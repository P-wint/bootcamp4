# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# determine the total number of schools
total_schools = len(school_data_complete.school_name.unique())

# determine the total number of students
total_students = school_data_complete.student_name.count()

# determine the total budget
total_budget = sum(school_data_complete.budget.unique())

# determine the average math score
average_math_score = school_data_complete.math_score.mean()

# determine the average reading score
average_reading_score = school_data_complete.reading_score.mean()

# determine the percentage of students with a passing math score (70 or greater)
passing_math_pct = (school_data_complete[school_data_complete["math_score"] >= 70].math_score.count())/total_students

# determine the percentage of students with a passing reading score (70 or greater)
passing_reading_pct = (school_data_complete[school_data_complete["reading_score"] >= 70].reading_score.count())/total_students

# determine the percentage of students with a passing math score (70 or greater)
overall_passing_rate = (passing_math_pct + passing_reading_pct)/2

# %%
# dataframe for storing the desired data
district_summary = pd.DataFrame({"Total unique Schools":[total_schools],
                                 "Total Students":total_students,
                                 "Total Budget":total_budget,
                                 "Average Math Score":average_math_score,
                                 "Average Reading Score":average_reading_score,
                                 "Percentage Passing Math":passing_math_pct*100,
                                 "Percentage Passing Reading":passing_reading_pct*100,
                                 "Percentage Overall Passing Rate":overall_passing_rate*100})

# reformat data
district_summary['Total Students'] = district_summary.apply(lambda x: "{:,.0f}".format(x['Total Students']), axis=1)
district_summary['Total Budget'] = district_summary.apply(lambda x: "${:,.2f}".format(x['Total Budget']), axis=1)

# Print Summary Dataframe
district_summary
# Out:
#    Total unique Schools Total Students    Total Budget  Average Math Score  \
# 0                    15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  Percentage Passing Math  Percentage Passing Reading  \
# 0               81.87784                74.980853                   85.805463
#
#    Percentage Overall Passing Rate
# 0                        80.393158

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
#Shool summary
school_summary = school_data_complete.groupby(['school_name'])
school_names = school_data_complete.school_name.sort_values().unique()
school_types = school_data.sort_values(by="school_name").type
school_total_students = list(school_summary.student_name.count())
school_budget = list(school_summary.budget.mean())
school_per_student_budget = [a/b for a,b in zip(school_budget,school_total_students)]
school_average_math_score = list(school_summary.math_score.mean())
school_average_reading_score = list(school_summary.reading_score.mean())

# Calculating passing percentages
school_summary = school_data_complete[school_data_complete['math_score'] >= 70].groupby(['school_name'])
school_pct_passing_math = [(a/b)*100 for a,b in zip(school_summary.math_score.count(),school_total_students)]
school_summary = school_data_complete[school_data_complete['reading_score'] >= 70].groupby(['school_name'])
school_pct_passing_reading = [(a/b)*100 for a, b in zip(school_summary.reading_score.count(), school_total_students)]
school_overall_passing = [(a+b)/2 for a,b in zip(school_pct_passing_math,school_pct_passing_reading)]

# Compile all calculations into dataframe
school_summary_df = pd.DataFrame({"School Names":school_names,
                                  "School Type":school_types,
                                  "Total Students":school_total_students,
                                  "Total School Budget":school_budget,
                                  "Per Student Budget":school_per_student_budget,
                                  "Average Math Score":school_avg_math_score,
                                  "Average Reading Score":school_avg_reading_score,
                                  "% Passing Math":school_pct_passing_math,
                                  "% Passing Reading":school_pct_passing_reading,
                                  "Overall Passing Rate":school_overall_passing})

school_summary_df = school_summary_df.reset_index(drop=True)
school_summary_df
# Out:
#              School Names School Type  Total Students  Total School Budget  \
# 0      Bailey High School    District            4976              3124928
# 1     Cabrera High School     Charter            1858              1081356
# 2    Figueroa High School    District            2949              1884411
# 3        Ford High School    District            2739              1763916
# 4     Griffin High School     Charter            1468               917500
# 5   Hernandez High School    District            4635              3022020
# 6      Holden High School     Charter             427               248087
# 7       Huang High School    District            2917              1910635
# 8     Johnson High School    District            4761              3094650
# 9        Pena High School     Charter             962               585858
# 10  Rodriguez High School    District            3999              2547363
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
# list the top five performing
top_5 = school_summary_df.sort_values(by='Overall Passing Rate', ascending=False).head(5).reset_index(drop=True)
top_5
# Out:
#           School Names School Type  Total Students  Total School Budget  \
# 0  Cabrera High School     Charter            1858              1081356
# 1   Thomas High School     Charter            1635              1043130
# 2     Pena High School     Charter             962               585858
# 3  Griffin High School     Charter            1468               917500
# 4   Wilson High School     Charter            2283              1319574
#
#    Per Student Budget  Average Math Score  Average Reading Score  \
# 0               582.0           83.061895              83.975780
# 1               638.0           83.418349              83.848930
# 2               609.0           83.839917              84.044699
# 3               625.0           83.351499              83.816757
# 4               578.0           83.274201              83.989488
#
#    % Passing Math  % Passing Reading  Overall Passing Rate
# 0       94.133477          97.039828             95.586652
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
#List the five worst schools
worst_5 = school_summary_df.sort_values(by='Overall Passing Rate', ascending=True).head(5).reset_index(drop=True)
worst_5
# Out:
#             School Names School Type  Total Students  Total School Budget  \
# 0  Rodriguez High School    District            3999              2547363
# 1   Figueroa High School    District            2949              1884411
# 2      Huang High School    District            2917              1910635
# 3    Johnson High School    District            4761              3094650
# 4       Ford High School    District            2739              1763916
#
#    Per Student Budget  Average Math Score  Average Reading Score  \
# 0               637.0           76.842711              80.744686
# 1               639.0           76.711767              81.158020
# 2               655.0           76.629414              81.182722
# 3               650.0           77.072464              80.966394
# 4               644.0           77.102592              80.746258
#
#    % Passing Math  % Passing Reading  Overall Passing Rate
# 0       66.366592          80.220055             73.293323
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
# a lists the average math Score for students of each grade level (9th, 10th, 11th, 12th) at each school
def average_math_by_grade(grade):
    school_summary = school_data_complete.loc[school_data_complete.grade ==grade].groupby(["school_name"])
    school_names = school_data_complete.school_name.sort_values().unique()
    school_average_math_score = list(school_summary.math_score.mean())

    #compile math calculations into df
    average_math_df = pd.DataFrame({"School Names":school_names,
                                    f"{grade} Average Math Score":school_average_math_score})
    
    average_math_df = average_math_df.reset_index(drop=True)
    return average_math_df

# %%
 # Reading score by grade and school   
grade9 = average_math_by_grade("9th")
grade10 = average_math_by_grade("10th")
grade11 = average_math_by_grade("11th")
grade12 = average_math_by_grade("12th")
average_math_score_by_grade = pd.merge(grade9, grade10, how = 'inner', suffixes=('',''))   
average_math_score_by_grade = pd.merge(average_math_score_by_grade, grade11, how = 'inner', suffixes=('',''))  
average_math_score_by_grade = pd.merge(average_math_score_by_grade, grade12, how = 'inner', suffixes=('',''))
average_math_score_by_grade
# Out:
#              School Names  9th Average Math Score  10th Average Math Score  \
# 0      Bailey High School               77.083676                76.996772
# 1     Cabrera High School               83.094697                83.154506
# 2    Figueroa High School               76.403037                76.539974
# 3        Ford High School               77.361345                77.672316
# 4     Griffin High School               82.044010                84.229064
# 5   Hernandez High School               77.438495                77.337408
# 6      Holden High School               83.787402                83.429825
# 7       Huang High School               77.027251                75.908735
# 8     Johnson High School               77.187857                76.691117
# 9        Pena High School               83.625455                83.372000
# 10  Rodriguez High School               76.859966                76.612500
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
# a lists the average reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school
def average_reading_by_grade(grade):
    school_summary = school_data_complete.loc[school_data_complete.grade ==grade].groupby(["school_name"])
    school_names = school_data_complete.school_name.sort_values().unique()
    school_average_reading_score = list(school_summary.reading_score.mean())

    #compile reading calculations into df
    average_reading_df = pd.DataFrame({"School Names":school_names,
                                    f"{grade} Average Reading Score":school_average_reading_score})
    
    average_reading_df = average_reading_df.reset_index(drop=True)
    return average_reading_df

# %%
 # Reading score by grade and school   
grade9 = average_reading_by_grade("9th")
grade10 = average_reading_by_grade("10th")
grade11 = average_reading_by_grade("11th")
grade12 = average_reading_by_grade("12th")
average_reading_score_by_grade = pd.merge(grade9, grade10, how = 'inner', suffixes=('',''))   
average_reading_score_by_grade = pd.merge(average_reading_score_by_grade, grade11, how = 'inner', suffixes=('',''))  
average_reading_score_by_grade = pd.merge(average_reading_score_by_grade, grade12, how = 'inner', suffixes=('',''))
average_reading_score_by_grade
# Out:
#              School Names  9th Average Reading Score  \
# 0      Bailey High School                  81.303155
# 1     Cabrera High School                  83.676136
# 2    Figueroa High School                  81.198598
# 3        Ford High School                  80.632653
# 4     Griffin High School                  83.369193
# 5   Hernandez High School                  80.866860
# 6      Holden High School                  83.677165
# 7       Huang High School                  81.290284
# 8     Johnson High School                  81.260714
# 9        Pena High School                  83.807273
# 10  Rodriguez High School                  80.993127
# 11    Shelton High School                  84.122642
# 12     Thomas High School                  83.728850
# 13     Wilson High School                  83.939778
# 14     Wright High School                  83.833333
#
#     10th Average Reading Score  11th Average Reading Score  \
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# bins based upon spending per student
spending_bins = [0, 580, 615, 645, 705]

# Create labels for these bins
group_labels = ["$0-$580", "$580-$615", "$615-$645", "$645-$705"]

scores_by_spending = school_summary_df[["School Names", 
                                       "Average Math Score",
                                       "Average Reading Score",
                                       "% Passing Math",
                                       "% Passing Reading",
                                       "Overall Passing Rate"]]
scores_by_spending["Spending Summary"] = pd.cut(school_summary_df["Per Student Budget"],spending_bins, labels=group_labels)
scores_by_spending= scores_by_spending.groupby(["Spending Summary"])
scores_by_spending.mean()
# Out:
# <ipython-input-11-61b2cf819e15>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores_by_spending["Spending Summary"] = pd.cut(school_summary_df["Per Student Budget"],spending_bins, labels=group_labels)
#                   Average Math Score  Average Reading Score  % Passing Math  \
# Spending Summary
# $0-$580                    83.274201              83.989488       93.867718
# $580-$615                  83.549353              83.903238       93.686876
# $615-$645                  79.079225              81.891436       75.668212
# $645-$705                  76.997210              81.027843       66.164813
#
#                   % Passing Reading  Overall Passing Rate
# Spending Summary
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# bins based upon spending per school size
school_size_bins = [0, 1500, 2500, 3750, 6000]

# Create labels for these bins
group_labels = ["0-1500", "1500-2500", "2500-3750", "3750-6000"]

scores_by_school_size = school_summary_df[["School Names", 
                                       "Average Math Score",
                                       "Average Reading Score",
                                       "% Passing Math",
                                       "% Passing Reading",
                                       "Overall Passing Rate"]]
scores_by_school_size["School Size Summary"] = pd.cut(school_summary_df["Total Students"],school_size_bins, labels=group_labels)
scores_by_school_size= scores_by_school_size.groupby(["School Size Summary"])
scores_by_school_size.mean()
# Out:
# <ipython-input-12-ed029ca2d366>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores_by_school_size["School Size Summary"] = pd.cut(school_summary_df["Total Students"],school_size_bins, labels=group_labels)
#                      Average Math Score  Average Reading Score  \
# School Size Summary
# 0-1500                        83.664898              83.892148
# 1500-2500                     83.359224              83.898984
# 2500-3750                     76.814591              81.029000
# 3750-6000                     77.063340              80.919864
#
#                      % Passing Math  % Passing Reading  Overall Passing Rate
# School Size Summary
# 0-1500                    93.497607          96.445946             94.971776
# ...

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# scores based on school type
scores_by_school_type = pd.DataFrame(scores_by_school_type)

# Create a GroupBy object based upon school type
scores_by_school_type = school_summary_df[["School Names", 
                                           "School Type",
                                           "Average Math Score",
                                           "Average Reading Score",
                                           "% Passing Math",
                                           "% Passing Reading",
                                           "Overall Passing Rate"]]
scores_by_school_type = scores_by_school_type.groupby("School Type")
scores_by_school_type.mean()
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  Overall Passing Rate
# School Type
# Charter              96.586489             95.103660
# District             80.799062             73.673757

# %%
Looking at the summary 'scores by school type', shows that Charter schools out perform the district schools both in Math and Reading.
We see where the size of the school is directly related to performance.  That is, the smaller the size of the school the better the outcomes 
tend to be. An interesting observation is, that spending is not as big a factor in outcome as one would have thought.  The higher 
spending per student does not correlate to better result in either subject.
